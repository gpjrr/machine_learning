# %%
import pandas as pd
import numpy as np

# %%
LittleX=np.array([
4096,8192
])

Intel=np.array([
675.8725084,
6747.582837

])
Ryzen=np.array([
841.3977716.
6550.243122

])
# Out:
#   Input In [56]
#     6550.243122
#     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
ax = plt.subplots()
ax=plt
## Float
## Double
## Short int
## Long int
ax.title("Metodo de Cannon con Long int")
ax.xlabel('Tamaño de la matriz')
ax.ylabel('Tiempo en segundos')
ax.plot(LittleX,Intel,'b-',label="i310100")
ax.plot(LittleX,Ryzen,'r-',label="ryzen52500U")
ax.grid(True)
plt.legend(loc='upper center')
ax.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
